# %%
from sqlalchemy import create_engine
import psycopg2 as pg
import pandas as pd

# Laczenie sie z baza danych z wykorzystaniem sqpAlchemy

db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"
db = create_engine(db_string)
connection_sqlalchemy = db.connect()

result_set = db.execute("SELECT * FROM city")  
for r in result_set:  
    print(r)
# Out:
# (1, 'A Corua (La Corua)', 87, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (2, 'Abha', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (3, 'Abu Dhabi', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (4, 'Acua', 60, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (5, 'Adana', 97, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (6, 'Addis Abeba', 31, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (7, 'Aden', 107, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (8, 'Adoni', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (9, 'Ahmadnagar', 44, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (10, 'Akishima', 50, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (11, 'Akron', 103, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (12, 'al-Ayn', 101, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (13, 'al-Hawiya', 82, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (14, 'al-Manama', 11, datetime.datetime(2006, 2, 15, 9, 45, 25))
# (15, 'al-Qadarif', 89, datetime.datetime(2006, 2, 15, 9, 45, 25))
# ...

# %%
# Laczenie sie z baza danych z wykorzystaniem psycopg2 i pandas

connection = pg.connect(host='pgsql-196447.vipserv.org', port=5432, dbname='wbauer_adb', user='wbauer_adb', password='adb2020')
df = pd.read_sql('select * from city',con=connection)
print(df)
# Out:
#      city_id                city  country_id         last_update
# 0          1  A Corua (La Corua)          87 2006-02-15 09:45:25
# 1          2                Abha          82 2006-02-15 09:45:25
# 2          3           Abu Dhabi         101 2006-02-15 09:45:25
# 3          4                Acua          60 2006-02-15 09:45:25
# 4          5               Adana          97 2006-02-15 09:45:25
# ..       ...                 ...         ...                 ...
# 595      596               Zaria          69 2006-02-15 09:45:25
# 596      597        Zeleznogorsk          80 2006-02-15 09:45:25
# 597      598         Zhezqazghan          51 2006-02-15 09:45:25
# 598      599            Zhoushan          23 2006-02-15 09:45:25
# 599      600          Ziguinchor          83 2006-02-15 09:45:25
#
# [600 rows x 4 columns]
# ...

# %%
# ZADANIE 1
# Ile kategorii filmów mamy w wypożyczalni?

df = pd.read_sql('select category_id from film_category order by category_id desc limit 1',con=connection)
print(df)

# w tym zadaniu wyswietlam kolumne z kategoriami filmow poukladanych w sposob malejaco
# i wyswietlam tylko pierwszy wiersz
# Out:
#    category_id
# 0           16
# C:\Users\Acer\AppData\Local\Temp/ipykernel_23104/2321738286.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('select category_id from film_category order by category_id desc limit 1',con=connection)

# %%
# ZADANIE 2
# Wyświetl listę kategorii w kolejności alfabetycznej.

df = pd.read_sql('select name from category order by name asc ',con=connection)
print(df)

# wykorzystuje w tym zadaniu komende asc w celu wyswietlenia imion alfabetycznie
# Out:
#            name
# 0        Action
# 1     Animation
# 2      Children
# 3      Classics
# 4        Comedy
# 5   Documentary
# 6         Drama
# 7        Family
# 8       Foreign
# 9         Games
# 10       Horror
# 11        Music
# 12          New
# 13       Sci-Fi
# 14       Sports
# 15       Travel
# C:\Users\Acer\AppData\Local\Temp/ipykernel_23104/2920024386.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('select name from category order by name asc ',con=connection)

# %%
# ZADANIE 3
# Znajdź najstarszy i najmłodszy film do wypożyczenia.

df = pd.read_sql('select distinct release_year from film',con=connection)
print(df)

# wykorzystalem komende do usuwania duplikatow, wiec najmlodszy oraz najstarszy film
# jest z 2006 roku
# Out:
#    release_year
# 0          2006
# C:\Users\Acer\AppData\Local\Temp/ipykernel_23104/3487375732.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('select distinct release_year from film',con=connection)

# %%
# ZADANIE 4
# Ile wypożyczeń odbyło się między 2005-07-01 a 2005-08-01?

result_set = db.execute("SELECT rental_date FROM rental WHERE rental_date BETWEEN '2005-07-01' AND '2005-08-01'")  
for r in result_set:  
    print(r)
print("Ilość wypożyczeń:", len(str(result_set)))
    
# w tym zadaniu wykorzystuje skladnie z sqlAlchemy, dodatkowo printuje dokladna ilosc wypozyczen
# Out:
# (datetime.datetime(2005, 7, 5, 22, 49, 24),)
# (datetime.datetime(2005, 7, 5, 22, 51, 44),)
# (datetime.datetime(2005, 7, 5, 22, 56, 33),)
# (datetime.datetime(2005, 7, 5, 22, 57, 34),)
# (datetime.datetime(2005, 7, 5, 22, 59, 53),)
# (datetime.datetime(2005, 7, 5, 23, 1, 21),)
# (datetime.datetime(2005, 7, 5, 23, 2, 37),)
# (datetime.datetime(2005, 7, 5, 23, 5, 17),)
# (datetime.datetime(2005, 7, 5, 23, 5, 44),)
# (datetime.datetime(2005, 7, 5, 23, 8, 53),)
# (datetime.datetime(2005, 7, 5, 23, 11, 43),)
# (datetime.datetime(2005, 7, 5, 23, 13, 7),)
# (datetime.datetime(2005, 7, 5, 23, 13, 22),)
# (datetime.datetime(2005, 7, 5, 23, 13, 51),)
# (datetime.datetime(2005, 7, 5, 23, 23, 11),)
# (datetime.datetime(2005, 7, 5, 23, 25, 54),)
# (datetime.datetime(2005, 7, 5, 23, 29, 55),)
# (datetime.datetime(2005, 7, 5, 23, 30, 36),)
# (datetime.datetime(2005, 7, 5, 23, 32, 49),)
# (datetime.datetime(2005, 7, 5, 23, 33, 40),)
# (datetime.datetime(2005, 7, 5, 23, 37, 13),)
# ...

# %%
# ZADANIE 5
# Ile wypożyczeń odbyło się między 2010-01-01 a 2011-02-01?

result_set = db.execute("SELECT rental_date FROM rental WHERE rental_date BETWEEN '2010-01-01' AND '2011-02-01'")  
for r in result_set:  
    print(r)

# nie wyswietla sie ani jedna data, takze najprawdopodobniej zadno wypozyczenie nie odbylo sie:)

# %%
# ZADANIE 6
# Znajdź największą płatność wypożyczenia.

df = pd.read_sql('select max(amount) from payment',con=connection)
print(df)

# skladnie funkcji max() znalazlem na internecie, poniewaz idealnie pasuje do tego zadania
# Out:
#      max
# 0  11.99
# C:\Users\Acer\AppData\Local\Temp/ipykernel_19828/1710034077.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('select max(amount) from payment',con=connection)

# %%
# ZADANIE 7
# Znajdź wszystkich klientów z Polski, Nigerii lub Bangladeszu.

df = pd.read_sql("""select customer.first_name, customer.last_name, country.country 
                    from customer 
                    inner join address on customer.address_id = address.address_id 
                    inner join city on address.city_id = city.city_id 
                    inner join country on city.country_id = country.country_id 
                    where country in ('Poland', 'Nigeria', 'Bangladesh')
                    order by country asc""",con=connection)
print(df)

# w tym przykladzie musialem wykorzystac komende inner join, ktora pozwolila na znalezienie czesci wspolnej roznych kolumn, dzieki
# czemu znalazlem wszystkich klientow z Polski, Nigerii i Bangladeszu
# Out:
#    first_name  last_name     country
# 0    Michelle      Clark  Bangladesh
# 1     Stephen     Qualls  Bangladesh
# 2       Frank   Waggoner  Bangladesh
# 3     Marilyn       Ross     Nigeria
# 4       Elsie     Kelley     Nigeria
# 5      Gladys   Hamilton     Nigeria
# 6       Sonia    Gregory     Nigeria
# 7      Rodney    Moeller     Nigeria
# 8       Velma      Lucas     Nigeria
# 9       Carol     Garcia     Nigeria
# 10       Olga    Jimenez     Nigeria
# 11     Bertha   Ferguson     Nigeria
# 12     Tracey    Barrett     Nigeria
# 13         Jo     Fowler     Nigeria
# 14    Wallace      Slone     Nigeria
# 15  Constance       Reid     Nigeria
# 16      Brian      Wyman      Poland
# 17     Sidney   Burleson      Poland
# 18   Marjorie     Tucker      Poland
# 19    Russell    Brinson      Poland
# 20       Leah     Curtis      Poland
# 21      Ruben      Geary      Poland
# 22    Johnnie   Chisholm      Poland
# 23     Jimmie  Eggleston      Poland
# ...

# %%
# ZADANIE 8
# Gdzie mieszkają członkowie personelu?

df = pd.read_sql("""select staff.first_name, staff.last_name, address.address, city.city, country.country 
                    from staff 
                    inner join address on staff.address_id = address.address_id 
                    inner join city on address.city_id = city.city_id 
                    inner join country on city.country_id = country.country_id
                    """,con=connection)
print(df)

# w tym zadaniu ponownie musialem wykorzystac pare razy komende inner join, aby znalezc wszystkich czlonkow personelu
# Out:
#   first_name last_name               address        city    country
# 0       Mike   Hillyer     23 Workhaven Lane  Lethbridge     Canada
# 1        Jon  Stephens  1411 Lillydale Drive   Woodridge  Australia
# C:\Users\Acer\AppData\Local\Temp/ipykernel_19828/2649274990.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("""select staff.first_name, staff.last_name, address.address, city.city, country.country from staff

# %%
# ZADANIE 9
# Ilu pracowników mieszka w Argentynie lub Hiszpanii?

df =  pd.read_sql("""select staff.first_name, staff.last_name, country.country ,city.city, address.address
                     from staff 
                     inner join address on staff.address_id = address.address_id inner join city 
                     on address.city_id = city.city_id inner join country on city.country_id = country.country_id
                     where country in ('Spain') or country in ('Argentina')
                     """,con=connection)
print(df)

# nie ma pracownikow, ktorzy miszkaja w Argentynie lub Hiszpanii
# Out:
# Empty DataFrame
# Columns: [first_name, last_name, country, city, address]
# Index: []
# C:\Users\Acer\AppData\Local\Temp/ipykernel_19828/3205328446.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df =  pd.read_sql("""select staff.first_name, staff.last_name, country.country ,city.city, address.address

# %%
# ZADANIE 10
# Jakie kategorie filmów zostały wypożyczone przez klientów?

df =  pd.read_sql("""select distinct category.name 
                     from rental 
                     inner join inventory on rental.inventory_id = inventory.inventory_id
                     inner join film_category on inventory.film_id = film_category.film_id
                     inner join category on category.category_id = film_category.category_id
                     """,con=connection)
print(df)

# w tym zadaniu pominalem kolumne film poniewaz, wiersz o nazwie film_id znajduje sie rowniez w kolumnie film_category, 
# wykorzystalem komende distinct, poniewaz bardzo duzo kategorii filmow sie powtarza
# Out:
#            name
# 0        Sports
# 1      Classics
# 2           New
# 3        Family
# 4        Comedy
# 5     Animation
# 6        Travel
# 7         Music
# 8         Drama
# 9        Horror
# 10       Sci-Fi
# 11        Games
# 12  Documentary
# 13      Foreign
# 14       Action
# 15     Children
# C:\Users\Acer\AppData\Local\Temp/ipykernel_19828/3120090853.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df =  pd.read_sql("""select distinct category.name from rental

# %%
# ZADANIE 11
# Znajdź wszystkie kategorie filmów wypożyczonych w Ameryce.

df =  pd.read_sql("""select distinct category.name, category.category_id, country.country 
                     from rental 
                     inner join inventory on rental.inventory_id = inventory.inventory_id
                     inner join film_category on inventory.film_id = film_category.film_id
                     inner join category on category.category_id = film_category.category_id
        
                     inner join customer on rental.customer_id = customer.customer_id
                     inner join address on address.address_id = customer.address_id
                     inner join city on address.city_id = city.city_id
                     inner join country on city.country_id = country.country_id
                     where country.country in ('Canada','United States','Mexico')
                     order by country asc
                     """,con=connection)
print(df)

# znalazlem wszystie kategorie filmow wypozyczone w calej Ameryce
# Out:
#            name  category_id        country
# 0        Action            1         Canada
# 1     Animation            2         Canada
# 2      Children            3         Canada
# 3      Classics            4         Canada
# 4        Comedy            5         Canada
# 5   Documentary            6         Canada
# 6         Drama            7         Canada
# 7        Family            8         Canada
# 8       Foreign            9         Canada
# 9         Games           10         Canada
# 10       Horror           11         Canada
# 11        Music           12         Canada
# 12          New           13         Canada
# 13       Sci-Fi           14         Canada
# 14       Sports           15         Canada
# 15       Travel           16         Canada
# 16       Action            1         Mexico
# 17    Animation            2         Mexico
# 18     Children            3         Mexico
# 19     Classics            4         Mexico
# ...

# %%
# ZADANIE 12
# Znajdź wszystkie tytuły filmów, w których grał: Olympia Pfeiffer lub Julia Zellweger lub Ellen Presley

df =  pd.read_sql("""select distinct actor.first_name, actor.last_name, film.title
                     from actor 
                     inner join film_actor on film_actor.actor_id = actor.actor_id
                     inner join film_category on film_category.film_id = film_actor.film_id
                     inner join film on film.film_id = film_category.film_id
                     where actor.first_name = 'Olympia' and actor.last_name = 'Pfeiffer'
                     or actor.first_name = 'Julia' and actor.last_name = 'Zellweger'
                     or actor.first_name = 'Ellen' and actor.last_name = 'Presley'
                     """,con=connection)
print(df)

# ponowanie musialem wykorzystac pare komend inner join aby po odpowiedniej drodze dojsc do wszystkich tytulow filmow, w ktorych
# grali dani aktorzy
# Out:
#    first_name  last_name            title
# 0       Ellen    Presley  Secretary Rouge
# 1       Ellen    Presley   Homeward Cider
# 2       Julia  Zellweger     Open African
# 3       Ellen    Presley     Network Peak
# 4       Julia  Zellweger  Hollow Jeopardy
# ..        ...        ...              ...
# 64      Ellen    Presley  Pinocchio Simon
# 65      Ellen    Presley     Private Drop
# 66      Ellen    Presley      Hyde Doctor
# 67      Ellen    Presley    Jacket Frisco
# 68      Julia  Zellweger  Majestic Floats
#
# [69 rows x 3 columns]
# C:\Users\Acer\AppData\Local\Temp/ipykernel_19828/1189841223.py:4: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df =  pd.read_sql("""select distinct actor.first_name, actor.last_name, film.title
